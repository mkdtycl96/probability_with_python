# %% [markdown]
# # CENTRAL LIMIT THEOREM

# %% [markdown]
# ## Sample Mean for a Uniform Distribution

# %%
import random
import math
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
random.seed(54312)

# %%
sample_size = 100

sim_num = 10000

# %%
mean_list = []

for i in range(sim_num):
    sample_list = []
    for i in range(sample_size):
        sample_list.append(random.randint(0, 100))
    sample_mean = sum(sample_list)/sample_size
    mean_list.append(sample_mean)

# %%
plt.hist(mean_list, bins=100, density=True, color='r')
plt.grid()
mu = 50
sigma = math.sqrt(((100 ** 2) / 12)) / (math.sqrt(sample_size))
x = np.linspace(mu-4*sigma, mu + 4*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
import seaborn as sns
sns.distplot(mean_list)
# Out:
# C:\Users\mkdty\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Sample Mean for a Exponential Distribution

# %%
sample_size = 40

sim_num = 10000

# %%
mean_list = []

for i in range(sim_num):
    sample_list = []
    for i in range(sample_size):
        sample_list.append(np.random.exponential(1))
    sample_mean = sum(sample_list)/sample_size
    mean_list.append(sample_mean)

# %%
plt.hist(mean_list, bins=100, density=True, color='r')
plt.grid()
mu = 1
sigma = 1/(math.sqrt(sample_size))
x = np.linspace(mu-4*sigma, mu + 4*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %% [markdown]
# # CONFIDENCE INTERVAL

# %%
sample_list = []

for i in range(30):
    sample_list.append(random.randint(0, 10))
    
random.seed(39809)

# %%
sample_mean = np.mean(sample_list)

sample_mean
# Out:
# 5.0

# %%
n = len(sample_list)

cl = 0.95

std = 1
np.std(sample_list)
# Out:
# 3.0876096471758427

# %%
(1-cl)/2 + cl
# Out:
# 0.975

# %%
critic_value = stats.norm.ppf(((1-cl)/2) + cl)

# %%
critic_value
# Out:
# 1.959963984540054

# %%
lower_limit = sample_mean - (critic_value * (std/math.sqrt(n)))
lower_limit
# Out:
# 4.175494504589902

# %%
upper_limit = sample_mean + (critic_value * (std/math.sqrt(n)))
upper_limit
# Out:
# 4.8911721620767645

# %%
print(f'Your {cl} z confidence interval is ({lower_limit:.2f}, {upper_limit:.2f})')
# Out:
# Your 0.95 z confidence interval is (5.18, 5.89)

# %% [markdown]
# # EXERCISE 1.
# Suppose scores on exams in statistics are normally distributed with an unknown population mean and a population standard deviation of 3 points. A random sample of 36 scores is taken and gives a sample mean (sample  mean score) of 68. Find a confidence interval estimate for the population mean exam score (the mean score on all exams).
#
# Find a 90% confidence interval for the true (population) mean of statistics exam scores.

# %%
a = 3/math.sqrt(36)
a
sample_mean1 = 68
stats.norm.interval(0.90, loc=68, scale=3/math.sqrt(36))
# Out:
# (67.17757318652427, 68.82242681347573)

# %%
critic_value = stats.norm.ppf((1-0.90)/2+0.90)
critic_value
# Out:
# 1.6448536269514722

# %%
((1-0.99)/2)+0.99
# Out:
# 0.995

# %%
stats.norm.ppf(0.05)
# Out:
# -1.6448536269514729

# %%
lower_limit = sample_mean1 - (critic_value * (3/math.sqrt(36)))

# %%
lower_limit
# Out:
# 67.17757318652427

# %%
upper_limit = sample_mean1 + (critic_value * (3/math.sqrt(36)))
upper_limit
# Out:
# 68.82242681347573

# %% [markdown]
# # EXERCISE -2
#
# 2. What is the normal body temperature for healthy humans? A random sample of 130 healthy human body temperatures provided by Allen Shoemaker7 yielded 98.25 degrees and standard deviation 0.73 degrees.
#
# Give a 99% confidence interval for the average body temperature of healthy people.

# %%
ci = 0.99
std = 0.73
sample_mean = 98.25

# %%
stats.norm.interval(0.99, loc=98.25, scale=std/math.sqrt(130))
# Out:
# (98.08508192246582, 98.41491807753418)

# %% [markdown]
# # EXERCISE 3.
#
# The administrators for a hospital wished to estimate the average number of days required for inpatient treatment of patients between the ages of 25 and 34. A random sample of 500 hospital patients between these ages produced a mean and standard deviation equal to 5.4 and 3.1 days, respectively.
#
#
# Construct a 95% confidence interval for the mean length of stay for the population of patients from which the sample was drawn.

# %%
ci = 0.95
std = 3.1
sample_mean = 5.4

# %%
stats.norm.interval(0.95, loc=sample_mean, scale=std/math.sqrt(500))
# Out:
# (5.12827801242126, 5.67172198757874)

# %%
critic_value = stats.norm.ppf(((1-0.95)/2)+0.95)

# %%
lower_limit = sample_mean - (critic_value * (std/math.sqrt(500)))

# %%
lower_limit
# Out:
# 5.12827801242126

# %%
upper_limit = sample_mean + (critic_value * (std/math.sqrt(500)))

# %%
upper_limit
# Out:
# 5.67172198757874

# %% [markdown]
# ## Exercise from Slides

# %%
sample_list = [2, 3, 5, 6, 9]

# %%
sample_mean = np.mean(sample_list)

sample_mean
# Out:
# 5.0

# %%
std = 2.5

# %%
n = len(sample_list)

# %%
cl = 0.95

# %%
((1-cl)/2) + cl
# Out:
# 0.975

# %%
critic_value = stats.norm.ppf(((1-cl)/2) + cl)
critic_value
# Out:
# 1.959963984540054

# %%
lower_limit = sample_mean - (critic_value * (std/math.sqrt(n)))
lower_limit
# Out:
# 3.160997738549714

# %%
upper_limit = sample_mean + (critic_value * (std/math.sqrt(n)))
upper_limit
# Out:
# 6.839002261450286

# %%
print(f'Your {cl} z confidence interval is ({lower_limit:.2f}, {upper_limit:.2f})')
# Out:
# Your 0.9 z confidence interval is (3.16, 6.84)

# %%
stats.norm.interval(cl, loc=sample_mean, scale=std/math.sqrt(n))
# Out:
# (3.160997738549713, 6.839002261450286)

# %% [markdown]
# ## Exercise

# %%
import pandas as pd

df = pd.read_csv("samples.csv")

# %%
sample_mean = df['Demand'].mean()
sample_mean
# Out:
# 370.16

# %%
std = 75

n = len(df['Demand'])

cl = 0.99

# %%
critic_value = stats.norm.ppf(((1-cl)/2) + cl)
critic_value
# Out:
# 2.5758293035489004

# %%
lower_limit = sample_mean - (critic_value * (std/math.sqrt(n)))
lower_limit
# Out:
# 331.52256044676653

# %%
upper_limit = sample_mean + (critic_value * (std/math.sqrt(n)))
upper_limit
# Out:
# 408.7974395532335

# %%
print(f'Your {cl} z confidence interval is ({lower_limit:.2f}, {upper_limit:.2f})')
# Out:
# Your 0.95 z confidence interval is (340.76, 399.56)

# %% [markdown]
# Using Scipy

# %%
stats.norm.interval(cl, loc=sample_mean, scale=std/math.sqrt(n))
# Out:
# (340.7605402318992, 399.55945976810085)

# %%
sample_mean = 38

std = 6.5

n = 25

cl = 0.95

# %%
stats.norm.interval(cl, loc=sample_mean, scale=std/math.sqrt(n))
# Out:
# (35.45204682009793, 40.54795317990207)

# %%
1 - stats.norm(2,0.1).cdf(2.2)
# Out:
# 0.022750131948179098

# %% [markdown]
# ## EXERCISE 4.
#
# The school board administered an IQ test to 20 randomly selected teachers. They found that the average IQ score was 114 with a standard deviation of 10. Assume that the cumulative probability is 0.90. What population mean would have produced this sample result?

# %%
stats.t.ppf(0.9, df=19) = 1.3277282090267986 = t.score
t.score = ( x - μ) / (std /karakök(20))
1.328 = (114-μ)/(10/karakök(20))
μ = 111
